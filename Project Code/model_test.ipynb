# %%
import os
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model

# %% [markdown]
# MODEL TEST FOR BENIGN

# %%
def load_images_from_single_class_dir(directory_path, image_size=(224, 224)):
    images = []
    labels = []
    image_paths = []
    class_name = os.path.basename(directory_path)
    class_dict = {class_name: 0}

    for filename in os.listdir(directory_path):
        if filename.endswith('.jpg') or filename.endswith('.png'):
            img_path = os.path.join(directory_path, filename)
            img = image.load_img(img_path, target_size=image_size)
            img_array = image.img_to_array(img) / 255.0
            images.append(img_array)
            labels.append(class_dict[class_name])
            image_paths.append(img_path)

    images = np.array(images)
    labels = np.array(labels)
    labels = np.expand_dims(labels, axis=-1)
    return images, labels, image_paths, class_dict

def evaluate_model_on_single_class_directory(model, directory_path):
    images, labels, image_paths, class_dict = load_images_from_single_class_dir(directory_path)

    predictions = model.predict(images)
    predicted_classes = np.argmax(predictions, axis=1)
    true_classes = labels.flatten()

    correct_predictions = np.sum(predicted_classes == true_classes)
    total_images = len(true_classes)

    print(f"Correctly detected images: {correct_predictions}/{total_images}")
    print(f"Accuracy: {correct_predictions / total_images * 100:.2f}%")

    false_predictions = []
    for i in range(len(predicted_classes)):
        if predicted_classes[i] != true_classes[i]:
            if predicted_classes[i] == 0:
                true_class_name = list(class_dict.keys())[list(class_dict.values()).index(true_classes[i])]
                predicted_class_name = list(class_dict.keys())[list(class_dict.values()).index(predicted_classes[i])]
                false_predictions.append((image_paths[i], true_class_name, predicted_class_name))
            else:
                print(f"Unexpected prediction class: {predicted_classes[i]} for image: {image_paths[i]}")

    print("\nFalse predictions:")
    for img_path, true_class_name, predicted_class_name in false_predictions:
        print(f"Image: {img_path} - True class: {true_class_name} - Predicted class: {predicted_class_name}")

model = load_model("..\\models\\model.h5")

directory_path = '..\\Dataset\\benign'
evaluate_model_on_single_class_directory(model, directory_path)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step
# Correctly detected images: 866/891
# Accuracy: 97.19%
# Unexpected prediction class: 2 for image: ..\Dataset\benign\benign (108).png
# Unexpected prediction class: 1 for image: ..\Dataset\benign\benign (114)_mask.png
# Unexpected prediction class: 1 for image: ..\Dataset\benign\benign (116).png
# Unexpected prediction class: 1 for image: ..\Dataset\benign\benign (119).png
# Unexpected prediction class: 1 for image: ..\Dataset\benign\benign (122).png
# Unexpected prediction class: 2 for image: ..\Dataset\benign\benign (269).png
# Unexpected prediction class: 1 for image: ..\Dataset\benign\benign (312).png
# Unexpected prediction class: 1 for image: ..\Dataset\benign\benign (333).png
# Unexpected prediction class: 2 for image: ..\Dataset\benign\benign (335).png
# Unexpected prediction class: 2 for image: ..\Dataset\benign\benign (363).png
# Unexpected prediction class: 2 for image: ..\Dataset\benign\benign (383).png
# Unexpected prediction class: 1 for image: ..\Dataset\benign\benign (392).png
# Unexpected prediction class: 1 for image: ..\Dataset\benign\benign (397).png
# Unexpected prediction class: 1 for image: ..\Dataset\benign\benign (404).png
# Unexpected prediction class: 1 for image: ..\Dataset\benign\benign (407).png
# Unexpected prediction class: 1 for image: ..\Dataset\benign\benign (410).png
# Unexpected prediction class: 1 for image: ..\Dataset\benign\benign (415).png
# Unexpected prediction class: 1 for image: ..\Dataset\benign\benign (421).png
# Unexpected prediction class: 1 for image: ..\Dataset\benign\benign (433).png
# Unexpected prediction class: 1 for image: ..\Dataset\benign\benign (435).png
# Unexpected prediction class: 2 for image: ..\Dataset\benign\benign (55).png
# Unexpected prediction class: 1 for image: ..\Dataset\benign\benign (64).png
# Unexpected prediction class: 1 for image: ..\Dataset\benign\benign (88).png
# Unexpected prediction class: 2 for image: ..\Dataset\benign\benign (94).png
# Unexpected prediction class: 1 for image: ..\Dataset\benign\benign (97).png
#
# False predictions:

# %% [markdown]
# MODEL TEST FOR MALIGNANT

# %%
def load_images_from_single_class_dir(directory_path, image_size=(224, 224)):
    images = []
    labels = []
    image_paths = []
    class_name = os.path.basename(directory_path)
    class_dict = {class_name: 1}

    for filename in os.listdir(directory_path):
        if filename.endswith('.jpg') or filename.endswith('.png'):
            img_path = os.path.join(directory_path, filename)
            img = image.load_img(img_path, target_size=image_size)
            img_array = image.img_to_array(img) / 255.0
            images.append(img_array)
            labels.append(class_dict[class_name])
            image_paths.append(img_path)

    images = np.array(images)
    labels = np.array(labels)
    labels = np.expand_dims(labels, axis=-1)
    return images, labels, image_paths, class_dict

def evaluate_model_on_single_class_directory(model, directory_path):
    images, labels, image_paths, class_dict = load_images_from_single_class_dir(directory_path)

    predictions = model.predict(images)
    predicted_classes = np.argmax(predictions, axis=1)
    true_classes = labels.flatten()

    correct_predictions = np.sum(predicted_classes == true_classes)
    total_images = len(true_classes)

    print(f"Correctly detected images: {correct_predictions}/{total_images}")
    print(f"Accuracy: {correct_predictions / total_images * 100:.2f}%")

    false_predictions = []
    for i in range(len(predicted_classes)):
        if predicted_classes[i] != true_classes[i]:
            if predicted_classes[i] == 1:
                true_class_name = list(class_dict.keys())[list(class_dict.values()).index(true_classes[i])]
                predicted_class_name = list(class_dict.keys())[list(class_dict.values()).index(predicted_classes[i])]
                false_predictions.append((image_paths[i], true_class_name, predicted_class_name))
            else:
                print(f"Unexpected prediction class: {predicted_classes[i]} for image: {image_paths[i]}")

    print("\nFalse predictions:")
    for img_path, true_class_name, predicted_class_name in false_predictions:
        print(f"Image: {img_path} - True class: {true_class_name} - Predicted class: {predicted_class_name}")

model = load_model("..\\models\\model.h5")

directory_path = '..\\Dataset\\malignant'
evaluate_model_on_single_class_directory(model, directory_path)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step
# Correctly detected images: 369/421
# Accuracy: 87.65%
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (1).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (10).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (105).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (109).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (11).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (110).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (112).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (112)_mask.png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (12).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (121).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (122).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (125).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (126).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (13).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (132).png
# Unexpected prediction class: 2 for image: ..\Dataset\malignant\malignant (136).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (138).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (141).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (143).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (148).png
# Unexpected prediction class: 2 for image: ..\Dataset\malignant\malignant (158).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (161).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (166).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (167).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (169)_mask.png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (174).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (180).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (181).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (193).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (2).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (200).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (206).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (207).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (26).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (27).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (28).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (38).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (44).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (46).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (51).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (52).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (53).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (55).png
# Unexpected prediction class: 2 for image: ..\Dataset\malignant\malignant (60).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (61).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (68).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (73).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (74).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (77).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (93).png
# Unexpected prediction class: 0 for image: ..\Dataset\malignant\malignant (94).png
# Unexpected prediction class: 2 for image: ..\Dataset\malignant\malignant (99).png
#
# False predictions:

# %% [markdown]
# MODEL TEST FOR NORMAL CLASS

# %%
def load_images_from_single_class_dir(directory_path, image_size=(224, 224)):
    images = []
    labels = []
    image_paths = []
    class_name = os.path.basename(directory_path)
    class_dict = {class_name: 2}

    for filename in os.listdir(directory_path):
        if filename.endswith('.jpg') or filename.endswith('.png'):
            img_path = os.path.join(directory_path, filename)
            img = image.load_img(img_path, target_size=image_size)
            img_array = image.img_to_array(img) / 255.0
            images.append(img_array)
            labels.append(class_dict[class_name])
            image_paths.append(img_path)

    images = np.array(images)
    labels = np.array(labels)
    labels = np.expand_dims(labels, axis=-1)
    return images, labels, image_paths, class_dict

def evaluate_model_on_single_class_directory(model, directory_path):
    images, labels, image_paths, class_dict = load_images_from_single_class_dir(directory_path)

    predictions = model.predict(images)
    predicted_classes = np.argmax(predictions, axis=1)
    true_classes = labels.flatten()

    correct_predictions = np.sum(predicted_classes == true_classes)
    total_images = len(true_classes)

    print(f"Correctly detected images: {correct_predictions}/{total_images}")
    print(f"Accuracy: {correct_predictions / total_images * 100:.2f}%")

    false_predictions = []
    for i in range(len(predicted_classes)):
        if predicted_classes[i] != true_classes[i]:
            if predicted_classes[i] == 2:
                true_class_name = list(class_dict.keys())[list(class_dict.values()).index(true_classes[i])]
                predicted_class_name = list(class_dict.keys())[list(class_dict.values()).index(predicted_classes[i])]
                false_predictions.append((image_paths[i], true_class_name, predicted_class_name))
            else:
                print(f"Unexpected prediction class: {predicted_classes[i]} for image: {image_paths[i]}")

    print("\nFalse predictions:")
    for img_path, true_class_name, predicted_class_name in false_predictions:
        print(f"Image: {img_path} - True class: {true_class_name} - Predicted class: {predicted_class_name}")

model = load_model("..\\models\\model.h5")

directory_path = '..\\Dataset\\normal'
evaluate_model_on_single_class_directory(model, directory_path)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step
# Correctly detected images: 245/266
# Accuracy: 92.11%
# Unexpected prediction class: 0 for image: ..\Dataset\normal\normal (1).png
# Unexpected prediction class: 1 for image: ..\Dataset\normal\normal (10).png
# Unexpected prediction class: 0 for image: ..\Dataset\normal\normal (108).png
# Unexpected prediction class: 0 for image: ..\Dataset\normal\normal (111).png
# Unexpected prediction class: 1 for image: ..\Dataset\normal\normal (116).png
# Unexpected prediction class: 0 for image: ..\Dataset\normal\normal (117).png
# Unexpected prediction class: 0 for image: ..\Dataset\normal\normal (118).png
# Unexpected prediction class: 0 for image: ..\Dataset\normal\normal (12).png
# Unexpected prediction class: 0 for image: ..\Dataset\normal\normal (122).png
# Unexpected prediction class: 0 for image: ..\Dataset\normal\normal (25).png
# Unexpected prediction class: 0 for image: ..\Dataset\normal\normal (34).png
# Unexpected prediction class: 0 for image: ..\Dataset\normal\normal (65).png
# Unexpected prediction class: 0 for image: ..\Dataset\normal\normal (74).png
# Unexpected prediction class: 0 for image: ..\Dataset\normal\normal (76).png
# Unexpected prediction class: 0 for image: ..\Dataset\normal\normal (77).png
# Unexpected prediction class: 0 for image: ..\Dataset\normal\normal (79).png
# Unexpected prediction class: 0 for image: ..\Dataset\normal\normal (80).png
# Unexpected prediction class: 0 for image: ..\Dataset\normal\normal (87).png
# Unexpected prediction class: 1 for image: ..\Dataset\normal\normal (9).png
# Unexpected prediction class: 0 for image: ..\Dataset\normal\normal (90).png
# Unexpected prediction class: 0 for image: ..\Dataset\normal\normal (91).png
#
# False predictions:
